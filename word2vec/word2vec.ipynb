# %%
import pandas as pd
import gensim
from sklearn.manifold import TSNE

from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
init_notebook_mode(connected=True)
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import random
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %% [markdown]
# # [Word2Vec Algorithm](https://en.wikipedia.org/wiki/Word2vec)
#
# ### What is it?
# It's a Natural Language Processing [NLP] algorithm that transforms words to vectors.
#
# ### When do I use it?
# When I want to explore semantics of words. For example: find word's oposites, find context word etc.
#
# ### Why should I use it?
# 1] NLP
#
# 2] It's a general idea of mapping string of elements onto vectors (and vectors are good to work with). I can use it for recommending next product or a song in playlist.

# %% [markdown]
# # How does it work?
#
# * Word2Vec is actualy shallow Neural Network [NN] (1 hidden layer).
#
# * **Starting point:**
#     * We have N words.
#     * Each word is represented by N-dimensional vector with 1 on index position and 0s elsewhere (one-hot encoding).
#
#
# * We let the NN predict word's naighbours.
#
#
# * We cut out only the guts of the trained NN - scored hidden leayer values for each word.
#
#
# * **End point:**
#     * Each word is represented by only M-dimension vector (M << N), that carries some context information.   **:-)**

# %% [markdown]
# ### Why is it important to have vectors instead of words? Because we have the Algebra!

# %% [markdown]
# ## Word2Vec: one-hot encoding
# <img src="one_hot.png" alt="one_hot" style="width: 600px;"/>

# %% [markdown]
# ## Word2Vec: Word2Vec output
# <img src="w2v_output.png" alt="w2v_output" style="width: 600px;"/>

# %% [markdown]
# ## Approaches:
# * **Skipgram** [SG]
#     * Uses neighbour words as an input to NN and central word as an output.
#
# * **Continuous Bag Of Words** [CBOW]
#     * Uses central word as an input to NN and neighbour words as an output.

# %% [markdown]
# ## Word2Vec: Word neighborhood
# <img src="word_neighbour.png" alt="word_neighbour" style="width: 600px;"/>

# %% [markdown]
# ## Word2Vec: Skipgram method
# <img src="skipgram.png" alt="skipgram" style="width: 600px;"/>

# %% [markdown]
# ## Word2Vec: CBOW method
# <img src="cbow.png" alt="skipgram" style="width: 600px;"/>

# %% [markdown]
# ## Dataset - QUORA

# %%
# Load the dataset
df = pd.read_csv("data/quora.csv")
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
# Transfer the dataset into list of lists
def read_questions(row,column_name):
    return gensim.utils.simple_preprocess(str(row[column_name]).encode('utf-8'))
    
documents = []
for index, row in df.iterrows():
    documents.append(read_questions(row,"question1"))
    if row["is_duplicate"] == 0:
        documents.append(read_questions(row,"question2"))

# %%
# document example 
documents[:4]
# Out:
# [['what',
#   'is',
#   'the',
#   'step',
#   'by',
#   'step',
#   'guide',
#   'to',
#   'invest',
#   'in',
#   'share',
#   'market',
#   'in',
#   'india'],
#  ['what',
#   'is',
#   'the',
#   'step',
#   'by',
#   'step',
#   'guide',
#   'to',
#   'invest',
#   'in',
#   'share',
#   'market'],
#  ['what', 'is', 'the', 'story', 'of', 'kohinoor', 'koh', 'noor', 'diamond'],
#  ['what',
#   'would',
#   'happen',
#   'if',
#   'the',
#   'indian',
#   'government',
#   'stole',
#   'the',
#   'kohinoor',
#   'koh',
#   'noor',
#   'diamond',
#   'back']]

# %% [markdown]
# ## Model build

# %%
# Lets train the word2vec model using skipgram/cbow
w2v_model = gensim.models.Word2Vec(size=150, window=10, min_count=5, sg=0, workers=10)
w2v_model.build_vocab(documents) 
w2v_model.train(sentences=documents, total_examples=len(documents), epochs=w2v_model.epochs)
# Out:
# (25176933, 35144510)

# %% [markdown]
# ## Model exploration

# %%
# Model vocabulary
print(f"Our vocabulary hase {len(w2v_model.wv.vocab)} words.")
w2v_model.wv.vocab
# Out:
# Our vocabulary hase 27775 words.
# {'what': <gensim.models.keyedvectors.Vocab at 0x16a82f780>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x15c867400>,
#  'the': <gensim.models.keyedvectors.Vocab at 0x15fd12ef0>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x15fd12d30>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x15fd12b70>,
#  'guide': <gensim.models.keyedvectors.Vocab at 0x15fd12898>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x15fd12780>,
#  'invest': <gensim.models.keyedvectors.Vocab at 0x15fd12668>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x15fd12550>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x15fd12438>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x15fd12320>,
#  'india': <gensim.models.keyedvectors.Vocab at 0x15fd12208>,
#  'story': <gensim.models.keyedvectors.Vocab at 0x15fd120f0>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x153c38780>,
#  'kohinoor': <gensim.models.keyedvectors.Vocab at 0x153c38ba8>,
#  'koh': <gensim.models.keyedvectors.Vocab at 0x153c38080>,
#  'noor': <gensim.models.keyedvectors.Vocab at 0x153c387f0>,
#  'diamond': <gensim.models.keyedvectors.Vocab at 0x153c38dd8>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x153c383c8>,
#  'happen': <gensim.models.keyedvectors.Vocab at 0x153c38c50>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x153c381d0>,
#  'indian': <gensim.models.keyedvectors.Vocab at 0x153c38978>,
#  'government': <gensim.models.keyedvectors.Vocab at 0x153c38f98>,
#  'stole': <gensim.models.keyedvectors.Vocab at 0x153cbcfd0>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x153cbcf98>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x153cbcf60>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x153cbcf28>,
#  'increase': <gensim.models.keyedvectors.Vocab at 0x153cbcef0>,
#  'speed': <gensim.models.keyedvectors.Vocab at 0x153cbceb8>,
#  'my': <gensim.models.keyedvectors.Vocab at 0x153cbce80>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x153cbce48>,
#  'connection': <gensim.models.keyedvectors.Vocab at 0x153cbce10>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x153cbcdd8>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x153cbcda0>,
#  'vpn': <gensim.models.keyedvectors.Vocab at 0x153cbcd68>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x153cbcd30>,
#  'increased': <gensim.models.keyedvectors.Vocab at 0x153cbccf8>,
#  'hacking': <gensim.models.keyedvectors.Vocab at 0x153cbccc0>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x153cbcc88>,
#  'dns': <gensim.models.keyedvectors.Vocab at 0x153cbcc50>,
#  'why': <gensim.models.keyedvectors.Vocab at 0x153cbcc18>,
#  'am': <gensim.models.keyedvectors.Vocab at 0x153cbcbe0>,
#  'mentally': <gensim.models.keyedvectors.Vocab at 0x153cbcba8>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x153cbcb70>,
#  'lonely': <gensim.models.keyedvectors.Vocab at 0x153cbcb38>,
#  'solve': <gensim.models.keyedvectors.Vocab at 0x153cbcb00>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x153cbcac8>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x153cbca90>,
#  'remainder': <gensim.models.keyedvectors.Vocab at 0x153cbca58>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x153cbca20>,
#  'math': <gensim.models.keyedvectors.Vocab at 0x153cbc9e8>,
#  'divided': <gensim.models.keyedvectors.Vocab at 0x153cbc9b0>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x153cbc978>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x153cbc940>,
#  'dissolve': <gensim.models.keyedvectors.Vocab at 0x153cbc908>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x153cbc8d0>,
#  'sugar': <gensim.models.keyedvectors.Vocab at 0x153cbc898>,
#  'salt': <gensim.models.keyedvectors.Vocab at 0x153cbc860>,
#  'methane': <gensim.models.keyedvectors.Vocab at 0x153cbc828>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x153cbc7f0>,
#  'carbon': <gensim.models.keyedvectors.Vocab at 0x153cbc7b8>,
#  'di': <gensim.models.keyedvectors.Vocab at 0x153cbc780>,
#  'oxide': <gensim.models.keyedvectors.Vocab at 0x153cbc748>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x153cbc710>,
#  'survive': <gensim.models.keyedvectors.Vocab at 0x153cbc6d8>,
#  'astrology': <gensim.models.keyedvectors.Vocab at 0x153cbc6a0>,
#  'capricorn': <gensim.models.keyedvectors.Vocab at 0x153cbc668>,
#  'sun': <gensim.models.keyedvectors.Vocab at 0x153cbc630>,
#  'cap': <gensim.models.keyedvectors.Vocab at 0x153cbc5f8>,
#  'moon': <gensim.models.keyedvectors.Vocab at 0x153cbc5c0>,
#  'rising': <gensim.models.keyedvectors.Vocab at 0x153cbc588>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x153cbc550>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x153cbc518>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x153cbc4e0>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x153cbc4a8>,
#  'me': <gensim.models.keyedvectors.Vocab at 0x153cbc470>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x153cbc438>,
#  'buy': <gensim.models.keyedvectors.Vocab at 0x153cbc400>,
#  'keeps': <gensim.models.keyedvectors.Vocab at 0x153cbc390>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x153cbc3c8>,
#  'far': <gensim.models.keyedvectors.Vocab at 0x153cbc240>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x153cbc278>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x153cbc0b8>,
#  'video': <gensim.models.keyedvectors.Vocab at 0x153cbc0f0>,
#  'games': <gensim.models.keyedvectors.Vocab at 0x153cbc358>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x153cbc1d0>,
#  'geologist': <gensim.models.keyedvectors.Vocab at 0x153cbc080>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x16aabb7b8>,
#  'you': <gensim.models.keyedvectors.Vocab at 0x16aabb4e0>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x16aabb3c8>,
#  'instead': <gensim.models.keyedvectors.Vocab at 0x16aabb198>,
#  'motorola': <gensim.models.keyedvectors.Vocab at 0x16aabb1d0>,
#  'company': <gensim.models.keyedvectors.Vocab at 0x16aabb128>,
#  'hack': <gensim.models.keyedvectors.Vocab at 0x16aabb0f0>,
#  'charter': <gensim.models.keyedvectors.Vocab at 0x16aabb0b8>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x16aabb048>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x16aabb668>,
#  'method': <gensim.models.keyedvectors.Vocab at 0x16aabb390>,
#  'separation': <gensim.models.keyedvectors.Vocab at 0x16aabbf60>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x16aabbf28>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x16aabbe48>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x16aabbe10>,
#  'technicians': <gensim.models.keyedvectors.Vocab at 0x16aabbd30>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x16aabbcf8>,
#  'durability': <gensim.models.keyedvectors.Vocab at 0x16aabbc18>,
#  'reliability': <gensim.models.keyedvectors.Vocab at 0x16aabbba8>,
#  'laptops': <gensim.models.keyedvectors.Vocab at 0x16aabb8d0>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x16aabb908>,
#  'components': <gensim.models.keyedvectors.Vocab at 0x16aabb780>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x153c47fd0>,
#  'youtube': <gensim.models.keyedvectors.Vocab at 0x153c47048>,
#  'comments': <gensim.models.keyedvectors.Vocab at 0x153c47358>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x153c474e0>,
#  'physics': <gensim.models.keyedvectors.Vocab at 0x153c47860>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x153c47be0>,
#  'learn': <gensim.models.keyedvectors.Vocab at 0x15f867be0>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x15f867c50>,
#  'your': <gensim.models.keyedvectors.Vocab at 0x15f867dd8>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x15f867ef0>,
#  'sexual': <gensim.models.keyedvectors.Vocab at 0x15f867f28>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x15f867f60>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x15f867f98>,
#  'laws': <gensim.models.keyedvectors.Vocab at 0x15f867fd0>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x15f867e48>,
#  'status': <gensim.models.keyedvectors.Vocab at 0x15f867128>,
#  'student': <gensim.models.keyedvectors.Vocab at 0x15f867160>,
#  'visa': <gensim.models.keyedvectors.Vocab at 0x15f8670b8>,
#  'green': <gensim.models.keyedvectors.Vocab at 0x15f8670f0>,
#  'card': <gensim.models.keyedvectors.Vocab at 0x15f867048>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x15f867240>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x15f867278>,
#  'compare': <gensim.models.keyedvectors.Vocab at 0x15f8671d0>,
#  'immigration': <gensim.models.keyedvectors.Vocab at 0x15f867208>,
#  'canada': <gensim.models.keyedvectors.Vocab at 0x15f867080>,
#  'japan': <gensim.models.keyedvectors.Vocab at 0x15f8672b0>,
#  'trump': <gensim.models.keyedvectors.Vocab at 0x15f8672e8>,
#  'presidency': <gensim.models.keyedvectors.Vocab at 0x15f867320>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x15f867400>,
#  'current': <gensim.models.keyedvectors.Vocab at 0x15f8673c8>,
#  'international': <gensim.models.keyedvectors.Vocab at 0x15f867358>,
#  'master': <gensim.models.keyedvectors.Vocab at 0x15f867390>,
#  'students': <gensim.models.keyedvectors.Vocab at 0x15f867438>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x15f867198>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x15f8674a8>,
#  'manipulation': <gensim.models.keyedvectors.Vocab at 0x15f8674e0>,
#  'girls': <gensim.models.keyedvectors.Vocab at 0x15f867518>,
#  'want': <gensim.models.keyedvectors.Vocab at 0x15f8675f8>,
#  'friends': <gensim.models.keyedvectors.Vocab at 0x15f8675c0>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x15f867550>,
#  'guy': <gensim.models.keyedvectors.Vocab at 0x15f867588>,
#  'reject': <gensim.models.keyedvectors.Vocab at 0x15f867630>,
#  'guys': <gensim.models.keyedvectors.Vocab at 0x15f867470>,
#  'feel': <gensim.models.keyedvectors.Vocab at 0x15f867748>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x15f867710>,
#  'rejecting': <gensim.models.keyedvectors.Vocab at 0x15f8676a0>,
#  'girl': <gensim.models.keyedvectors.Vocab at 0x15f8676d8>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x15f867780>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x15f8677b8>,
#  'quora': <gensim.models.keyedvectors.Vocab at 0x15f867828>,
#  'users': <gensim.models.keyedvectors.Vocab at 0x15f867860>,
#  'posting': <gensim.models.keyedvectors.Vocab at 0x15f867898>,
#  'questions': <gensim.models.keyedvectors.Vocab at 0x15f8677f0>,
#  'readily': <gensim.models.keyedvectors.Vocab at 0x15f867668>,
#  'answered': <gensim.models.keyedvectors.Vocab at 0x15f867908>,
#  'google': <gensim.models.keyedvectors.Vocab at 0x15f867940>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x15f867978>,
#  'digital': <gensim.models.keyedvectors.Vocab at 0x15f8679b0>,
#  'marketing': <gensim.models.keyedvectors.Vocab at 0x15f8679e8>,
#  'institution': <gensim.models.keyedvectors.Vocab at 0x15f867a90>,
#  'banglore': <gensim.models.keyedvectors.Vocab at 0x15f867a20>,
#  'institute': <gensim.models.keyedvectors.Vocab at 0x15f867b70>,
#  'pune': <gensim.models.keyedvectors.Vocab at 0x15f867b00>,
#  'rockets': <gensim.models.keyedvectors.Vocab at 0x15f867a58>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x15f867ac8>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x15f867b38>,
#  'causing': <gensim.models.keyedvectors.Vocab at 0x15f867c88>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x15f867c18>,
#  'jealous': <gensim.models.keyedvectors.Vocab at 0x15f867ba8>,
#  'avoid': <gensim.models.keyedvectors.Vocab at 0x154488ba8>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x1544884a8>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x154488cf8>,
#  'ask': <gensim.models.keyedvectors.Vocab at 0x154488588>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x154488c18>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x154488630>,
#  'kv': <gensim.models.keyedvectors.Vocab at 0x1544887f0>,
#  'hp': <gensim.models.keyedvectors.Vocab at 0x154488668>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x1544887b8>,
#  'conversion': <gensim.models.keyedvectors.Vocab at 0x1544885f8>,
#  'chart': <gensim.models.keyedvectors.Vocab at 0x154488b38>,
#  'cc': <gensim.models.keyedvectors.Vocab at 0x154488748>,
#  'horsepower': <gensim.models.keyedvectors.Vocab at 0x154488c50>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x154488b70>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x154488320>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x1544889b0>,
#  'clock': <gensim.models.keyedvectors.Vocab at 0x1544882b0>,
#  'numbers': <gensim.models.keyedvectors.Vocab at 0x154488160>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x154488f28>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x165751e80>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x165751c50>,
#  'hands': <gensim.models.keyedvectors.Vocab at 0x165751a20>,
#  'overlap': <gensim.models.keyedvectors.Vocab at 0x165751780>,
#  'tips': <gensim.models.keyedvectors.Vocab at 0x165751400>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x165751128>,
#  'job': <gensim.models.keyedvectors.Vocab at 0x15f279cc0>,
#  'interview': <gensim.models.keyedvectors.Vocab at 0x15f279b38>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x15f279b00>,
#  'medicines': <gensim.models.keyedvectors.Vocab at 0x15f279ac8>,
#  'foundation': <gensim.models.keyedvectors.Vocab at 0x15f279a90>,
#  'medicine': <gensim.models.keyedvectors.Vocab at 0x15f279a20>,
#  'web': <gensim.models.keyedvectors.Vocab at 0x15f2799e8>,
#  'application': <gensim.models.keyedvectors.Vocab at 0x15f2799b0>,
#  'framework': <gensim.models.keyedvectors.Vocab at 0x15f279978>,
#  'society': <gensim.models.keyedvectors.Vocab at 0x15f279748>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x15f279710>,
#  'too': <gensim.models.keyedvectors.Vocab at 0x15f279a58>,
#  'importance': <gensim.models.keyedvectors.Vocab at 0x153ad8f60>,
#  'sports': <gensim.models.keyedvectors.Vocab at 0x153ad8da0>,
#  'contribute': <gensim.models.keyedvectors.Vocab at 0x153ad8be0>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x153ad8a20>,
#  'money': <gensim.models.keyedvectors.Vocab at 0x153ad8588>,
#  'online': <gensim.models.keyedvectors.Vocab at 0x153ad8898>,
#  'prepare': <gensim.models.keyedvectors.Vocab at 0x153ad8748>,
#  'ca': <gensim.models.keyedvectors.Vocab at 0x153ad8710>,
#  'final': <gensim.models.keyedvectors.Vocab at 0x153ad85c0>,
#  'law': <gensim.models.keyedvectors.Vocab at 0x153ad8470>,
#  'thing': <gensim.models.keyedvectors.Vocab at 0x153ad8358>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x153ad8240>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x153ad8128>,
#  'knowing': <gensim.models.keyedvectors.Vocab at 0x15f863278>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x15f8632b0>,
#  'cares': <gensim.models.keyedvectors.Vocab at 0x15f863470>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x15f863400>,
#  'gets': <gensim.models.keyedvectors.Vocab at 0x15f863048>,
#  'stuffy': <gensim.models.keyedvectors.Vocab at 0x15f8630b8>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x15f8635c0>,
#  'night': <gensim.models.keyedvectors.Vocab at 0x15f8635f8>,
#  'game': <gensim.models.keyedvectors.Vocab at 0x15f863710>,
#  'thrones': <gensim.models.keyedvectors.Vocab at 0x15f863748>,
#  'villain': <gensim.models.keyedvectors.Vocab at 0x15f863780>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x15f8637b8>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x15f8637f0>,
#  'give': <gensim.models.keyedvectors.Vocab at 0x15f863828>,
#  'mercy': <gensim.models.keyedvectors.Vocab at 0x15f863978>,
#  'united': <gensim.models.keyedvectors.Vocab at 0x15f8639b0>,
#  'states': <gensim.models.keyedvectors.Vocab at 0x15f8639e8>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x15f863a20>,
#  'blacklist': <gensim.models.keyedvectors.Vocab at 0x15f863a58>,
#  'employment': <gensim.models.keyedvectors.Vocab at 0x15f863a90>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x15f863c18>,
#  'citizens': <gensim.models.keyedvectors.Vocab at 0x15f863c50>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x15f863be0>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x15f863cc0>,
#  'political': <gensim.models.keyedvectors.Vocab at 0x15f863d30>,
#  'views': <gensim.models.keyedvectors.Vocab at 0x15f863f28>,
#  'average': <gensim.models.keyedvectors.Vocab at 0x15f863c88>,
#  'gas': <gensim.models.keyedvectors.Vocab at 0x15f863f98>,
#  'molecules': <gensim.models.keyedvectors.Vocab at 0x1686baa58>,
#  'determined': <gensim.models.keyedvectors.Vocab at 0x1686bac18>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x1686baef0>,
#  'website': <gensim.models.keyedvectors.Vocab at 0x1686ba048>,
#  'spain': <gensim.models.keyedvectors.Vocab at 0x1686ba1d0>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x1686ba550>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x16aac2eb8>,
#  'obama': <gensim.models.keyedvectors.Vocab at 0x16aac2e10>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x16aac2f60>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x16aac2d68>,
#  'take': <gensim.models.keyedvectors.Vocab at 0x16aac2d30>,
#  'guns': <gensim.models.keyedvectors.Vocab at 0x16aac2ef0>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x16aac2cc0>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x16aac2be0>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x16aac2ba8>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x16aac2ac8>,
#  'gun': <gensim.models.keyedvectors.Vocab at 0x16aac2a90>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x16aac27f0>,
#  'initiative': <gensim.models.keyedvectors.Vocab at 0x16aac22e8>,
#  'already': <gensim.models.keyedvectors.Vocab at 0x16aac22b0>,
#  'own': <gensim.models.keyedvectors.Vocab at 0x16aac2278>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x16aac2240>,
#  'old': <gensim.models.keyedvectors.Vocab at 0x16aac2208>,
#  'improve': <gensim.models.keyedvectors.Vocab at 0x16aac21d0>,
#  'skills': <gensim.models.keyedvectors.Vocab at 0x16aac2198>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x16aac2160>,
#  'become': <gensim.models.keyedvectors.Vocab at 0x16aac2128>,
#  'entrepreneur': <gensim.models.keyedvectors.Vocab at 0x16aac20f0>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x16aac20b8>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x16aac2080>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x16aac2048>,
#  'billionaire': <gensim.models.keyedvectors.Vocab at 0x16aac2358>,
#  'girlfriend': <gensim.models.keyedvectors.Vocab at 0x153cdaf28>,
#  'asks': <gensim.models.keyedvectors.Vocab at 0x153cdaf60>,
#  'her': <gensim.models.keyedvectors.Vocab at 0x153cdaeb8>,
#  'boyfriend': <gensim.models.keyedvectors.Vocab at 0x153cdacc0>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x153cdadd8>,
#  'choose': <gensim.models.keyedvectors.Vocab at 0x153cdac88>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x153cdab70>,
#  'reply': <gensim.models.keyedvectors.Vocab at 0x153cdaba8>,
#  'said': <gensim.models.keyedvectors.Vocab at 0x153cdaa20>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x153cdaa90>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x153cda940>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x153cda978>,
#  'she': <gensim.models.keyedvectors.Vocab at 0x153cda9b0>,
#  'confused': <gensim.models.keyedvectors.Vocab at 0x153cda630>,
#  'feelings': <gensim.models.keyedvectors.Vocab at 0x153cdaa58>,
#  'wished': <gensim.models.keyedvectors.Vocab at 0x153cda828>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x153cda7b8>,
#  'disconnected': <gensim.models.keyedvectors.Vocab at 0x153cda908>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x153cda780>,
#  'wants': <gensim.models.keyedvectors.Vocab at 0x153cda8d0>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x153cda748>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x153cda6d8>,
#  'upsc': <gensim.models.keyedvectors.Vocab at 0x153cda898>,
#  'stall': <gensim.models.keyedvectors.Vocab at 0x153cda6a0>,
#  'wings': <gensim.models.keyedvectors.Vocab at 0x153cda710>,
#  'fully': <gensim.models.keyedvectors.Vocab at 0x153cda860>,
#  'swept': <gensim.models.keyedvectors.Vocab at 0x153cda5c0>,
#  'aircraft': <gensim.models.keyedvectors.Vocab at 0x153cda668>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x153cda7f0>,
#  'variable': <gensim.models.keyedvectors.Vocab at 0x153cda4a8>,
#  'sweep': <gensim.models.keyedvectors.Vocab at 0x153cda4e0>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x153cda358>,
#  'slavs': <gensim.models.keyedvectors.Vocab at 0x153cda390>,
#  'squat': <gensim.models.keyedvectors.Vocab at 0x153cda1d0>,
#  'squats': <gensim.models.keyedvectors.Vocab at 0x153cda160>,
#  'legs': <gensim.models.keyedvectors.Vocab at 0x153cda240>,
#  'thicker': <gensim.models.keyedvectors.Vocab at 0x153cda198>,
#  'expect': <gensim.models.keyedvectors.Vocab at 0x153cda208>,
#  'cognizant': <gensim.models.keyedvectors.Vocab at 0x153cda0f0>,
#  'confirmation': <gensim.models.keyedvectors.Vocab at 0x153cda128>,
#  'mail': <gensim.models.keyedvectors.Vocab at 0x153cda080>,
#  'month': <gensim.models.keyedvectors.Vocab at 0x153cda0b8>,
#  'trading': <gensim.models.keyedvectors.Vocab at 0x153cda048>,
#  'kid': <gensim.models.keyedvectors.Vocab at 0x153cdae10>,
#  'rebel': <gensim.models.keyedvectors.Vocab at 0x153cdab38>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x153cda470>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x153cda2e8>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x16a82ca90>,
#  'bored': <gensim.models.keyedvectors.Vocab at 0x16a82c978>,
#  'universities': <gensim.models.keyedvectors.Vocab at 0x16a82c860>,
#  'recruit': <gensim.models.keyedvectors.Vocab at 0x16a82c748>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x16a82c278>,
#  'grads': <gensim.models.keyedvectors.Vocab at 0x16a82c160>,
#  'majors': <gensim.models.keyedvectors.Vocab at 0x16a82cba8>,
#  'looking': <gensim.models.keyedvectors.Vocab at 0x16a7cb400>,
#  'foods': <gensim.models.keyedvectors.Vocab at 0x16a7cb518>,
#  'quickest': <gensim.models.keyedvectors.Vocab at 0x16a7cb3c8>,
#  'instagram': <gensim.models.keyedvectors.Vocab at 0x16a7cb4e0>,
#  'followers': <gensim.models.keyedvectors.Vocab at 0x16a7cbdd8>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x16a7cb0b8>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x16a7cbda0>,
#  'darth': <gensim.models.keyedvectors.Vocab at 0x16a7cbb70>,
#  'vader': <gensim.models.keyedvectors.Vocab at 0x16a7cb2e8>,
#  'fought': <gensim.models.keyedvectors.Vocab at 0x16a7cba90>,
#  'maul': <gensim.models.keyedvectors.Vocab at 0x16a7cb860>,
#  'star': <gensim.models.keyedvectors.Vocab at 0x16a7cb828>,
#  'wars': <gensim.models.keyedvectors.Vocab at 0x16a7cb5f8>,
#  'legends': <gensim.models.keyedvectors.Vocab at 0x16a7cb2b0>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x16a7cb1d0>,
#  'character': <gensim.models.keyedvectors.Vocab at 0x16a7cb198>,
#  'limit': <gensim.models.keyedvectors.Vocab at 0x16a7cb080>,
#  'profile': <gensim.models.keyedvectors.Vocab at 0x15faa2c50>,
#  'descriptions': <gensim.models.keyedvectors.Vocab at 0x15faa2a90>,
#  'stages': <gensim.models.keyedvectors.Vocab at 0x15faa2940>,
#  'breaking': <gensim.models.keyedvectors.Vocab at 0x15faa2780>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x15faa2748>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x15faa2320>,
#  'couple': <gensim.models.keyedvectors.Vocab at 0x15faa22e8>,
#  'happens': <gensim.models.keyedvectors.Vocab at 0x15faa21d0>,
#  'emotionally': <gensim.models.keyedvectors.Vocab at 0x15faa2198>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x15faa2fd0>,
#  'male': <gensim.models.keyedvectors.Vocab at 0x15faa2f98>,
#  'female': <gensim.models.keyedvectors.Vocab at 0x15faa2eb8>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x15faa2e80>,
#  'affected': <gensim.models.keyedvectors.Vocab at 0x16a7f6a20>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x16a7f69b0>,
#  'breakup': <gensim.models.keyedvectors.Vocab at 0x16a7f6630>,
#  'boy': <gensim.models.keyedvectors.Vocab at 0x16a7f65f8>,
#  'examples': <gensim.models.keyedvectors.Vocab at 0x16a7f63c8>,
#  'products': <gensim.models.keyedvectors.Vocab at 0x16a7f6390>,
#  'crude': <gensim.models.keyedvectors.Vocab at 0x16a7f6208>,
#  'oil': <gensim.models.keyedvectors.Vocab at 0x16a7f61d0>,
#  'career': <gensim.models.keyedvectors.Vocab at 0x15f84be10>,
#  'launcher': <gensim.models.keyedvectors.Vocab at 0x15f84bdd8>,
#  'rbi': <gensim.models.keyedvectors.Vocab at 0x15f84bc88>,
#  'grade': <gensim.models.keyedvectors.Vocab at 0x15f84bc50>,
#  'preparation': <gensim.models.keyedvectors.Vocab at 0x15f84bb00>,
#  'blu': <gensim.models.keyedvectors.Vocab at 0x15f84bac8>,
#  'ray': <gensim.models.keyedvectors.Vocab at 0x15f84b978>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x15f84b940>,
#  'regular': <gensim.models.keyedvectors.Vocab at 0x15f84b7f0>,
#  'dvd': <gensim.models.keyedvectors.Vocab at 0x15f84b7b8>,
#  'player': <gensim.models.keyedvectors.Vocab at 0x15f84b6a0>,
#  'nd': <gensim.models.keyedvectors.Vocab at 0x15f84b668>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x15f84b518>,
#  'sad': <gensim.models.keyedvectors.Vocab at 0x15f84b4e0>,
#  'rotates': <gensim.models.keyedvectors.Vocab at 0x15f84b4a8>,
#  'memorable': <gensim.models.keyedvectors.Vocab at 0x15f84b470>,
#  've': <gensim.models.keyedvectors.Vocab at 0x15f84b358>,
#  'ever': <gensim.models.keyedvectors.Vocab at 0x15f84b320>,
#  'eaten': <gensim.models.keyedvectors.Vocab at 0x15f84b208>,
#  'gst': <gensim.models.keyedvectors.Vocab at 0x15f84b1d0>,
#  'affects': <gensim.models.keyedvectors.Vocab at 0x15f84b080>,
#  'cas': <gensim.models.keyedvectors.Vocab at 0x15f84b048>,
#  'tax': <gensim.models.keyedvectors.Vocab at 0x15f48d7b8>,
#  'officers': <gensim.models.keyedvectors.Vocab at 0x15f48d828>,
#  'homework': <gensim.models.keyedvectors.Vocab at 0x15f48d1d0>,
#  'difficult': <gensim.models.keyedvectors.Vocab at 0x15f48d0b8>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x15f48de10>,
#  'rsi': <gensim.models.keyedvectors.Vocab at 0x15f48df60>,
#  'apply': <gensim.models.keyedvectors.Vocab at 0x15f2b6358>,
#  'programs': <gensim.models.keyedvectors.Vocab at 0x16a78ccf8>,
#  're': <gensim.models.keyedvectors.Vocab at 0x16a78ccc0>,
#  'senior': <gensim.models.keyedvectors.Vocab at 0x16a78c9b0>,
#  'friend': <gensim.models.keyedvectors.Vocab at 0x16a78c978>,
#  'lying': <gensim.models.keyedvectors.Vocab at 0x16a78c748>,
#  'his': <gensim.models.keyedvectors.Vocab at 0x16a78c668>,
#  'true': <gensim.models.keyedvectors.Vocab at 0x16a78c400>,
#  'he': <gensim.models.keyedvectors.Vocab at 0x16a78c320>,
#  'secretly': <gensim.models.keyedvectors.Vocab at 0x16a78c0f0>,
#  'attracted': <gensim.models.keyedvectors.Vocab at 0x16a78c0b8>,
#  'rap': <gensim.models.keyedvectors.Vocab at 0x16a83ac88>,
#  'songs': <gensim.models.keyedvectors.Vocab at 0x16a83ac50>,
#  'dance': <gensim.models.keyedvectors.Vocab at 0x16a83a860>,
#  'suddenly': <gensim.models.keyedvectors.Vocab at 0x16a83a748>,
#  'logged': <gensim.models.keyedvectors.Vocab at 0x16a83a710>,
#  'off': <gensim.models.keyedvectors.Vocab at 0x16a83a5f8>,
#  'gmail': <gensim.models.keyedvectors.Vocab at 0x16a83a5c0>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x16a83a4a8>,
#  'password': <gensim.models.keyedvectors.Vocab at 0x16a83a208>,
#  'just': <gensim.models.keyedvectors.Vocab at 0x16a83a1d0>,
#  'realized': <gensim.models.keyedvectors.Vocab at 0x16a83a0b8>,
#  'recovery': <gensim.models.keyedvectors.Vocab at 0x16a83a080>,
#  'email': <gensim.models.keyedvectors.Vocab at 0x16a83ae10>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x16a83acf8>,
#  'longer': <gensim.models.keyedvectors.Vocab at 0x16573d400>,
#  'alive': <gensim.models.keyedvectors.Vocab at 0x16573d2e8>,
#  'ways': <gensim.models.keyedvectors.Vocab at 0x16573df28>,
#  'french': <gensim.models.keyedvectors.Vocab at 0x16573dd68>,
#  'genders': <gensim.models.keyedvectors.Vocab at 0x15f104a20>,
#  'download': <gensim.models.keyedvectors.Vocab at 0x15f104780>,
#  'content': <gensim.models.keyedvectors.Vocab at 0x15f964e80>,
#  'kickass': <gensim.models.keyedvectors.Vocab at 0x15f964f60>,
#  'torrent': <gensim.models.keyedvectors.Vocab at 0x15f964f98>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x15f964eb8>,
#  'registration': <gensim.models.keyedvectors.Vocab at 0x15f964320>,
#  'torrents': <gensim.models.keyedvectors.Vocab at 0x15f964780>,
#  'trustworthy': <gensim.models.keyedvectors.Vocab at 0x15f964c88>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x15f964f28>,
#  'dark': <gensim.models.keyedvectors.Vocab at 0x15f964fd0>,
#  'ring': <gensim.models.keyedvectors.Vocab at 0x15f9648d0>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x153cd1fd0>,
#  'iris': <gensim.models.keyedvectors.Vocab at 0x153cd1f60>,
#  'eye': <gensim.models.keyedvectors.Vocab at 0x153cd1eb8>,
#  'causes': <gensim.models.keyedvectors.Vocab at 0x153cd1f28>,
#  'treated': <gensim.models.keyedvectors.Vocab at 0x153cd1d30>,
#  'harry': <gensim.models.keyedvectors.Vocab at 0x153cd1e48>,
#  'potter': <gensim.models.keyedvectors.Vocab at 0x153cd1cf8>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x153cd1e10>,
#  'cursed': <gensim.models.keyedvectors.Vocab at 0x153cd1cc0>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x153cd1dd8>,
#  'depressed': <gensim.models.keyedvectors.Vocab at 0x153cd1c88>,
#  'evening': <gensim.models.keyedvectors.Vocab at 0x153cd1da0>,
#  'european': <gensim.models.keyedvectors.Vocab at 0x153cd1748>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x153cd17b8>,
#  'office': <gensim.models.keyedvectors.Vocab at 0x153cd1710>,
#  'database': <gensim.models.keyedvectors.Vocab at 0x153cd1518>,
#  'java': <gensim.models.keyedvectors.Vocab at 0x153cd1630>,
#  'programming': <gensim.models.keyedvectors.Vocab at 0x153cd13c8>,
#  'language': <gensim.models.keyedvectors.Vocab at 0x153cd15f8>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x153cd11d0>,
#  'store': <gensim.models.keyedvectors.Vocab at 0x153cd1208>,
#  'energy': <gensim.models.keyedvectors.Vocab at 0x153cd12b0>,
#  'produced': <gensim.models.keyedvectors.Vocab at 0x153cd12e8>,
#  'lightning': <gensim.models.keyedvectors.Vocab at 0x153cd1160>,
#  'review': <gensim.models.keyedvectors.Vocab at 0x153cd10b8>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x153c3deb8>,
#  'testing': <gensim.models.keyedvectors.Vocab at 0x153c3dbe0>,
#  'cost': <gensim.models.keyedvectors.Vocab at 0x153c3d9b0>,
#  'privacy': <gensim.models.keyedvectors.Vocab at 0x153c3d780>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x153c3d550>,
#  'germany': <gensim.models.keyedvectors.Vocab at 0x153c3d320>,
#  'come': <gensim.models.keyedvectors.Vocab at 0x153c3d0f0>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x15fbbd390>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x15fbbd358>,
#  'gain': <gensim.models.keyedvectors.Vocab at 0x15fbbd320>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x15fbbd2e8>,
#  'genuinely': <gensim.models.keyedvectors.Vocab at 0x15fbbd2b0>,
#  'enjoy': <gensim.models.keyedvectors.Vocab at 0x15fbbd278>,
#  'salad': <gensim.models.keyedvectors.Vocab at 0x15fbbd240>,
#  'dressing': <gensim.models.keyedvectors.Vocab at 0x15fbbd208>,
#  'types': <gensim.models.keyedvectors.Vocab at 0x15fbbd1d0>,
#  'immunity': <gensim.models.keyedvectors.Vocab at 0x15fbbd0b8>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x15fbbd080>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x15fbbde10>,
#  'narcissistic': <gensim.models.keyedvectors.Vocab at 0x15fbbddd8>,
#  'personality': <gensim.models.keyedvectors.Vocab at 0x15fbbdc18>,
#  'disorder': <gensim.models.keyedvectors.Vocab at 0x15fbbdbe0>,
#  'speak': <gensim.models.keyedvectors.Vocab at 0x15fbbdb00>,
#  'english': <gensim.models.keyedvectors.Vocab at 0x15fbbdac8>,
#  'fluently': <gensim.models.keyedvectors.Vocab at 0x15fbbd7f0>,
#  'helpful': <gensim.models.keyedvectors.Vocab at 0x15fbbd7b8>,
#  'quickbooks': <gensim.models.keyedvectors.Vocab at 0x15fbbd668>,
#  'auto': <gensim.models.keyedvectors.Vocab at 0x15fbbd630>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x15fbbd518>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x15fbbd4e0>,
#  'recover': <gensim.models.keyedvectors.Vocab at 0x15fbbd3c8>,
#  'corrupted': <gensim.models.keyedvectors.Vocab at 0x16a83c898>,
#  'files': <gensim.models.keyedvectors.Vocab at 0x16a83c748>,
#  'richest': <gensim.models.keyedvectors.Vocab at 0x16a83c470>,
#  'gambler': <gensim.models.keyedvectors.Vocab at 0x16a83c320>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x16a83c1d0>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x16a83c080>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x16a83cef0>,
#  'fire': <gensim.models.keyedvectors.Vocab at 0x16a83cda0>,
#  'bullet': <gensim.models.keyedvectors.Vocab at 0x16a83cc50>,
#  'backward': <gensim.models.keyedvectors.Vocab at 0x15fa1b400>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x15fa1bd68>,
#  'faster': <gensim.models.keyedvectors.Vocab at 0x15fa1bf28>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x15fa1b240>,
#  'backwards': <gensim.models.keyedvectors.Vocab at 0x15fa1bba8>,
#  'bullets': <gensim.models.keyedvectors.Vocab at 0x15fa1b9e8>,
#  'sound': <gensim.models.keyedvectors.Vocab at 0x15fa1b828>,
#  'shot': <gensim.models.keyedvectors.Vocab at 0x15fa1b6a0>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x15fa1b5c0>,
#  'occurs': <gensim.models.keyedvectors.Vocab at 0x15fa1b4e0>,
#  'prevent': <gensim.models.keyedvectors.Vocab at 0x16868bfd0>,
#  'breast': <gensim.models.keyedvectors.Vocab at 0x16868bef0>,
#  'cancer': <gensim.models.keyedvectors.Vocab at 0x16868beb8>,
#  'log': <gensim.models.keyedvectors.Vocab at 0x16868bdd8>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x16868bda0>,
#  'account': <gensim.models.keyedvectors.Vocab at 0x16868bcc0>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x16868bc88>,
#  'telling': <gensim.models.keyedvectors.Vocab at 0x16868bba8>,
#  'ip': <gensim.models.keyedvectors.Vocab at 0x16868bb70>,
#  'address': <gensim.models.keyedvectors.Vocab at 0x16868ba90>,
#  'device': <gensim.models.keyedvectors.Vocab at 0x16868ba58>,
#  'name': <gensim.models.keyedvectors.Vocab at 0x16868b978>,
#  'excluding': <gensim.models.keyedvectors.Vocab at 0x16868b940>,
#  'selling': <gensim.models.keyedvectors.Vocab at 0x16868b860>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x16868b828>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x16868b748>,
#  'bjp': <gensim.models.keyedvectors.Vocab at 0x16868b710>,
#  'strip': <gensim.models.keyedvectors.Vocab at 0x16868b630>,
#  'muslims': <gensim.models.keyedvectors.Vocab at 0x16868b5f8>,
#  'christians': <gensim.models.keyedvectors.Vocab at 0x16868b518>,
#  'citizenship': <gensim.models.keyedvectors.Vocab at 0x16868b4e0>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x16868b400>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x16868b3c8>,
#  'boats': <gensim.models.keyedvectors.Vocab at 0x16868b2e8>,
#  'rohingya': <gensim.models.keyedvectors.Vocab at 0x16868b2b0>,
#  'burma': <gensim.models.keyedvectors.Vocab at 0x16868b1d0>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x16868b198>,
#  'deport': <gensim.models.keyedvectors.Vocab at 0x16868b0b8>,
#  'illegal': <gensim.models.keyedvectors.Vocab at 0x16868b080>,
#  'bangladeshis': <gensim.models.keyedvectors.Vocab at 0x15fba8f28>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x15fba8ef0>,
#  'etiquette': <gensim.models.keyedvectors.Vocab at 0x15fba8dd8>,
#  'wishing': <gensim.models.keyedvectors.Vocab at 0x15fba8da0>,
#  'jehovah': <gensim.models.keyedvectors.Vocab at 0x15fba8c88>,
#  'witness': <gensim.models.keyedvectors.Vocab at 0x15fba8c50>,
#  'happy': <gensim.models.keyedvectors.Vocab at 0x15fba8b38>,
#  'birthday': <gensim.models.keyedvectors.Vocab at 0x15fba8b00>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x15fba89e8>,
#  'person': <gensim.models.keyedvectors.Vocab at 0x15fba89b0>,
#  'wish': <gensim.models.keyedvectors.Vocab at 0x15fba8898>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x15fba8860>,
#  'commercial': <gensim.models.keyedvectors.Vocab at 0x15fba8748>,
#  'fm': <gensim.models.keyedvectors.Vocab at 0x15fba8710>,
#  'radio': <gensim.models.keyedvectors.Vocab at 0x15fba85f8>,
#  'station': <gensim.models.keyedvectors.Vocab at 0x15fba85c0>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x15fba84a8>,
#  'procedure': <gensim.models.keyedvectors.Vocab at 0x15fba8470>,
#  'clip': <gensim.models.keyedvectors.Vocab at 0x15fba8358>,
#  'hd': <gensim.models.keyedvectors.Vocab at 0x15fba8320>,
#  'zealand': <gensim.models.keyedvectors.Vocab at 0x15fba8208>,
#  'swiss': <gensim.models.keyedvectors.Vocab at 0x15fba81d0>,
#  'despise': <gensim.models.keyedvectors.Vocab at 0x15fba80b8>,
#  'asians': <gensim.models.keyedvectors.Vocab at 0x15fba8080>,
#  'technical': <gensim.models.keyedvectors.Vocab at 0x15f2c89b0>,
#  'employees': <gensim.models.keyedvectors.Vocab at 0x15f1efeb8>,
#  'sales': <gensim.models.keyedvectors.Vocab at 0x15f1efb38>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x15f1efac8>,
#  'salary': <gensim.models.keyedvectors.Vocab at 0x15f1efa20>,
#  'income': <gensim.models.keyedvectors.Vocab at 0x15f1ef9b0>,
#  'jobs': <gensim.models.keyedvectors.Vocab at 0x15f1ef940>,
#  'field': <gensim.models.keyedvectors.Vocab at 0x15f1ef8d0>,
#  'biotechnology': <gensim.models.keyedvectors.Vocab at 0x15f1ef828>,
#  'height': <gensim.models.keyedvectors.Vocab at 0x15f1ef7b8>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x15f1ef208>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x15f1ef860>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x16aad2f28>,
#  'effects': <gensim.models.keyedvectors.Vocab at 0x16aad2ef0>,
#  'cambodia': <gensim.models.keyedvectors.Vocab at 0x16aad2dd8>,
#  'earthquake': <gensim.models.keyedvectors.Vocab at 0x16aad2da0>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x16aad2c88>,
#  'kamchatca': <gensim.models.keyedvectors.Vocab at 0x16aad2c50>,
#  'earthquakes': <gensim.models.keyedvectors.Vocab at 0x16aad2b38>,
#  'difference': <gensim.models.keyedvectors.Vocab at 0x16aad2b00>,
#  'fairness': <gensim.models.keyedvectors.Vocab at 0x16aad29e8>,
#  'honest': <gensim.models.keyedvectors.Vocab at 0x16aad29b0>,
#  'sincere': <gensim.models.keyedvectors.Vocab at 0x16aad2898>,
#  'gaming': <gensim.models.keyedvectors.Vocab at 0x16aad2860>,
#  'laptop': <gensim.models.keyedvectors.Vocab at 0x16aad2748>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x16aad2710>,
#  'inr': <gensim.models.keyedvectors.Vocab at 0x16aad25f8>,
#  'warrior': <gensim.models.keyedvectors.Vocab at 0x16aad25c0>,
#  'proving': <gensim.models.keyedvectors.Vocab at 0x16aad24a8>,
#  'grounds': <gensim.models.keyedvectors.Vocab at 0x16aad2470>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x16aad2358>,
#  'reference': <gensim.models.keyedvectors.Vocab at 0x16aad2320>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x16aad2208>,
#  'th': <gensim.models.keyedvectors.Vocab at 0x16aad21d0>,
#  'chemistry': <gensim.models.keyedvectors.Vocab at 0x16aad20b8>,
#  'cbse': <gensim.models.keyedvectors.Vocab at 0x16aad2080>,
#  'board': <gensim.models.keyedvectors.Vocab at 0x15faa1f60>,
#  'national': <gensim.models.keyedvectors.Vocab at 0x15faa1e48>,
#  'technology': <gensim.models.keyedvectors.Vocab at 0x15faa1d30>,
#  'kurukshetra': <gensim.models.keyedvectors.Vocab at 0x15faa1cc0>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x15faa1c50>,
#  'nitk': <gensim.models.keyedvectors.Vocab at 0x15faa1b38>,
#  'surathkal': <gensim.models.keyedvectors.Vocab at 0x15faa1a20>,
#  'karnataka': <gensim.models.keyedvectors.Vocab at 0x15faa1908>,
#  'graduating': <gensim.models.keyedvectors.Vocab at 0x15faa17f0>,
#  'batch': <gensim.models.keyedvectors.Vocab at 0x15faa16a0>,
#  'lessons': <gensim.models.keyedvectors.Vocab at 0x15faa1550>,
#  'juniors': <gensim.models.keyedvectors.Vocab at 0x15faa1358>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x15faa11d0>,
#  'leave': <gensim.models.keyedvectors.Vocab at 0x15faa14e0>,
#  'romantic': <gensim.models.keyedvectors.Vocab at 0x16aad1f28>,
#  'movies': <gensim.models.keyedvectors.Vocab at 0x16aad1ef0>,
#  'nightmare': <gensim.models.keyedvectors.Vocab at 0x16aad1dd8>,
#  'abstract': <gensim.models.keyedvectors.Vocab at 0x16aad1da0>,
#  'painting': <gensim.models.keyedvectors.Vocab at 0x16aad1c88>,
#  'influences': <gensim.models.keyedvectors.Vocab at 0x16aad1c50>,
#  'printing': <gensim.models.keyedvectors.Vocab at 0x16aad1b38>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x16aad1b00>,
#  'attend': <gensim.models.keyedvectors.Vocab at 0x16aad19e8>,
#  'caltech': <gensim.models.keyedvectors.Vocab at 0x16aad19b0>,
#  'jeremy': <gensim.models.keyedvectors.Vocab at 0x16aad1898>,
#  'notable': <gensim.models.keyedvectors.Vocab at 0x16aad1860>,
#  'folks': <gensim.models.keyedvectors.Vocab at 0x16aad1748>,
#  'attended': <gensim.models.keyedvectors.Vocab at 0x16aad1710>,
#  'horcrux': <gensim.models.keyedvectors.Vocab at 0x16aad15f8>,
#  'associate': <gensim.models.keyedvectors.Vocab at 0x16aad15c0>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x16aad14a8>,
#  'manager': <gensim.models.keyedvectors.Vocab at 0x16aad1470>,
#  'apm': <gensim.models.keyedvectors.Vocab at 0x16aad1358>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x16aad1320>,
#  'join': <gensim.models.keyedvectors.Vocab at 0x16aad1208>,
#  'management': <gensim.models.keyedvectors.Vocab at 0x16aad11d0>,
#  'rewarding': <gensim.models.keyedvectors.Vocab at 0x16aad10b8>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x16aad1080>,
#  'requirement': <gensim.models.keyedvectors.Vocab at 0x15eaabd68>,
#  'program': <gensim.models.keyedvectors.Vocab at 0x15eaab208>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x15eaab320>,
#  'software': <gensim.models.keyedvectors.Vocab at 0x15eaab470>,
#  'skype': <gensim.models.keyedvectors.Vocab at 0x15f481f28>,
#  'busy': <gensim.models.keyedvectors.Vocab at 0x15f481fd0>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x15f44f0b8>,
#  'android': <gensim.models.keyedvectors.Vocab at 0x15f44f048>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x153a20470>,
#  'war': <gensim.models.keyedvectors.Vocab at 0x16a7ddf28>,
#  'pakistan': <gensim.models.keyedvectors.Vocab at 0x16a7ddc50>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x16a7dd898>,
#  'uri': <gensim.models.keyedvectors.Vocab at 0x16a7dd5c0>,
#  'attack': <gensim.models.keyedvectors.Vocab at 0x16a7dd208>,
#  'ronald': <gensim.models.keyedvectors.Vocab at 0x16a823f60>,
#  'reagan': <gensim.models.keyedvectors.Vocab at 0x16a823e48>,
#  'speech': <gensim.models.keyedvectors.Vocab at 0x16a823d30>,
#  'react': <gensim.models.keyedvectors.Vocab at 0x16a823c18>,
#  'strategies': <gensim.models.keyedvectors.Vocab at 0x16a823b00>,
#  'union': <gensim.models.keyedvectors.Vocab at 0x16a8239e8>,
#  'civil': <gensim.models.keyedvectors.Vocab at 0x16a8238d0>,
#  'possibly': <gensim.models.keyedvectors.Vocab at 0x16a8237b8>,
#  'defeated': <gensim.models.keyedvectors.Vocab at 0x16a8236a0>,
#  'forces': <gensim.models.keyedvectors.Vocab at 0x16a823588>,
#  'gettysburg': <gensim.models.keyedvectors.Vocab at 0x16a823470>,
#  'american': <gensim.models.keyedvectors.Vocab at 0x16a823358>,
#  'fiction': <gensim.models.keyedvectors.Vocab at 0x16a823240>,
#  'novel': <gensim.models.keyedvectors.Vocab at 0x16a823128>,
#  'novels': <gensim.models.keyedvectors.Vocab at 0x16aabef28>,
#  'forgot': <gensim.models.keyedvectors.Vocab at 0x16aabeef0>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x16aabedd8>,
#  'demonetisation': <gensim.models.keyedvectors.Vocab at 0x16aabeda0>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x16aabec88>,
#  'higher': <gensim.models.keyedvectors.Vocab at 0x16aabec50>,
#  'gdp': <gensim.models.keyedvectors.Vocab at 0x16aabeb38>,
#  'affect': <gensim.models.keyedvectors.Vocab at 0x16aabeb00>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x16aabe9e8>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x16aabe9b0>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x16aabe898>,
#  'whatsapp': <gensim.models.keyedvectors.Vocab at 0x16aabe860>,
#  'hacked': <gensim.models.keyedvectors.Vocab at 0x16aabe748>,
#  'love': <gensim.models.keyedvectors.Vocab at 0x16aabe710>,
#  'pity': <gensim.models.keyedvectors.Vocab at 0x16aabe5f8>,
#  'competitive': <gensim.models.keyedvectors.Vocab at 0x16aabe5c0>,
#  'hiring': <gensim.models.keyedvectors.Vocab at 0x16aabe4a8>,
#  'republic': <gensim.models.keyedvectors.Vocab at 0x16aabe470>,
#  'bank': <gensim.models.keyedvectors.Vocab at 0x16aabe358>,
#  'helps': <gensim.models.keyedvectors.Vocab at 0x16aabe320>,
#  'spam': <gensim.models.keyedvectors.Vocab at 0x16aabe208>,
#  'ranking': <gensim.models.keyedvectors.Vocab at 0x16aabe1d0>,
#  'adjustment': <gensim.models.keyedvectors.Vocab at 0x16aabe0b8>,
#  'search': <gensim.models.keyedvectors.Vocab at 0x16aabe080>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x15fbf1c18>,
#  'traffic': <gensim.models.keyedvectors.Vocab at 0x15fbf18d0>,
#  'organic': <gensim.models.keyedvectors.Vocab at 0x15fbf1278>,
#  'vs': <gensim.models.keyedvectors.Vocab at 0x1686a3940>,
#  'rankings': <gensim.models.keyedvectors.Vocab at 0x1686a3748>,
#  'page': <gensim.models.keyedvectors.Vocab at 0x1686a35c0>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x1686a30b8>,
#  'watch': <gensim.models.keyedvectors.Vocab at 0x1686a3128>,
#  'subtitles': <gensim.models.keyedvectors.Vocab at 0x1686a31d0>,
#  'usa': <gensim.models.keyedvectors.Vocab at 0x1686a3668>,
#  'powerful': <gensim.models.keyedvectors.Vocab at 0x1686a36d8>,
#  'country': <gensim.models.keyedvectors.Vocab at 0x1686a37b8>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x1686a38d0>,
#  'obtain': <gensim.models.keyedvectors.Vocab at 0x1686a3b38>,
#  'instant': <gensim.models.keyedvectors.Vocab at 0x1686a3358>,
#  'ulcer': <gensim.models.keyedvectors.Vocab at 0x1686a3f98>,
#  'pain': <gensim.models.keyedvectors.Vocab at 0x1686a3c88>,
#  'relief': <gensim.models.keyedvectors.Vocab at 0x1686a3be0>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x1686a3ac8>,
#  'heat': <gensim.models.keyedvectors.Vocab at 0x1686a3e80>,
#  'ice': <gensim.models.keyedvectors.Vocab at 0x1686a3908>,
#  'china': <gensim.models.keyedvectors.Vocab at 0x15f447f60>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x15f447f28>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x15f447ef0>,
#  'advantage': <gensim.models.keyedvectors.Vocab at 0x15f447eb8>,
#  'worse': <gensim.models.keyedvectors.Vocab at 0x15f447e80>,
#  'materialistic': <gensim.models.keyedvectors.Vocab at 0x15f447e48>,
#  'cry': <gensim.models.keyedvectors.Vocab at 0x15f447d68>,
#  'stick': <gensim.models.keyedvectors.Vocab at 0x15f447cf8>,
#  'tongues': <gensim.models.keyedvectors.Vocab at 0x15f447e10>,
#  'pictures': <gensim.models.keyedvectors.Vocab at 0x16aaf1f28>,
#  'teen': <gensim.models.keyedvectors.Vocab at 0x16aaf1ef0>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x16aaf1dd8>,
#  'allow': <gensim.models.keyedvectors.Vocab at 0x16aaf1da0>,
#  'boyfriends': <gensim.models.keyedvectors.Vocab at 0x16aaf1c88>,
#  'naked': <gensim.models.keyedvectors.Vocab at 0x16aaf1c50>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x16aaf1b38>,
#  'ending': <gensim.models.keyedvectors.Vocab at 0x16aaf1b00>,
#  'depressing': <gensim.models.keyedvectors.Vocab at 0x16aaf19e8>,
#  'winston': <gensim.models.keyedvectors.Vocab at 0x16aaf19b0>,
#  'julia': <gensim.models.keyedvectors.Vocab at 0x16aaf1898>,
#  'differ': <gensim.models.keyedvectors.Vocab at 0x16aaf1860>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x16aaf1748>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x16aaf1710>,
#  'blowing': <gensim.models.keyedvectors.Vocab at 0x16aaf15f8>,
#  'computer': <gensim.models.keyedvectors.Vocab at 0x16aaf15c0>,
#  'tools': <gensim.models.keyedvectors.Vocab at 0x16aaf14a8>,
#  'exist': <gensim.models.keyedvectors.Vocab at 0x16aaf1470>,
#  'don': <gensim.models.keyedvectors.Vocab at 0x16aaf1358>,
#  'technologies': <gensim.models.keyedvectors.Vocab at 0x16aaf1320>,
#  'toothbrush': <gensim.models.keyedvectors.Vocab at 0x16aaf1208>,
#  'wet': <gensim.models.keyedvectors.Vocab at 0x16aaf11d0>,
#  'dry': <gensim.models.keyedvectors.Vocab at 0x16aaf10b8>,
#  'applying': <gensim.models.keyedvectors.Vocab at 0x16aaf1080>,
#  'toothpaste': <gensim.models.keyedvectors.Vocab at 0x16869e0b8>,
#  'cheapest': <gensim.models.keyedvectors.Vocab at 0x16869e240>,
#  'marked': <gensim.models.keyedvectors.Vocab at 0x16869e4e0>,
#  'needing': <gensim.models.keyedvectors.Vocab at 0x16869e780>,
#  'imrovement': <gensim.models.keyedvectors.Vocab at 0x16869e9b0>,
#  'neutral': <gensim.models.keyedvectors.Vocab at 0x16869e9e8>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x16869ec18>,
#  'buffer': <gensim.models.keyedvectors.Vocab at 0x16869ec50>,
#  'declared': <gensim.models.keyedvectors.Vocab at 0x16869ee80>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x16869eeb8>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x16869e208>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x16869e390>,
#  'win': <gensim.models.keyedvectors.Vocab at 0x16869e4a8>,
#  'mineral': <gensim.models.keyedvectors.Vocab at 0x16869e5f8>,
#  'holds': <gensim.models.keyedvectors.Vocab at 0x16869e748>,
#  'highest': <gensim.models.keyedvectors.Vocab at 0x16869e898>,
#  'electrical': <gensim.models.keyedvectors.Vocab at 0x16869eb00>,
#  'charge': <gensim.models.keyedvectors.Vocab at 0x16869ed68>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x16869e048>,
#  'mystery': <gensim.models.keyedvectors.Vocab at 0x16869e908>,
#  'universe': <gensim.models.keyedvectors.Vocab at 0x16869eb70>,
#  'alternative': <gensim.models.keyedvectors.Vocab at 0x16869edd8>,
#  'machine': <gensim.models.keyedvectors.Vocab at 0x16869e160>,
#  'learning': <gensim.models.keyedvectors.Vocab at 0x16869ec88>,
#  'sample': <gensim.models.keyedvectors.Vocab at 0x16869eef0>,
#  'multi': <gensim.models.keyedvectors.Vocab at 0x16869ef98>,
#  'imbalance': <gensim.models.keyedvectors.Vocab at 0x16869e400>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x16869e7b8>,
#  'block': <gensim.models.keyedvectors.Vocab at 0x16869e278>,
#  'sanctions': <gensim.models.keyedvectors.Vocab at 0x16869ea20>,
#  'un': <gensim.models.keyedvectors.Vocab at 0x16869e2e8>,
#  'mohammad': <gensim.models.keyedvectors.Vocab at 0x16866f438>,
#  'jem': <gensim.models.keyedvectors.Vocab at 0x16866fc88>,
#  'chief': <gensim.models.keyedvectors.Vocab at 0x16866f1d0>,
#  'masood': <gensim.models.keyedvectors.Vocab at 0x16866fb00>,
#  'azhar': <gensim.models.keyedvectors.Vocab at 0x16866f978>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x16866f710>,
#  'budget': <gensim.models.keyedvectors.Vocab at 0x16866ff98>,
#  'meaning': <gensim.models.keyedvectors.Vocab at 0x16aabaf28>,
#  'excessive': <gensim.models.keyedvectors.Vocab at 0x16aabaef0>,
#  'amounts': <gensim.models.keyedvectors.Vocab at 0x16aabadd8>,
#  'vitamin': <gensim.models.keyedvectors.Vocab at 0x16aabada0>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x16aabac88>,
#  'miscarriage': <gensim.models.keyedvectors.Vocab at 0x16aabac50>,
#  'glass': <gensim.models.keyedvectors.Vocab at 0x16aabab38>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x16aabab00>,
#  'scale': <gensim.models.keyedvectors.Vocab at 0x16aaba9e8>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x16aaba9b0>,
#  'letter': <gensim.models.keyedvectors.Vocab at 0x16aaba898>,
#  'intent': <gensim.models.keyedvectors.Vocab at 0x16aaba860>,
#  'recruitment': <gensim.models.keyedvectors.Vocab at 0x16aaba748>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x16aaba710>,
#  'com': <gensim.models.keyedvectors.Vocab at 0x16aaba5f8>,
#  'mantras': <gensim.models.keyedvectors.Vocab at 0x16aaba5c0>,
#  'mantra': <gensim.models.keyedvectors.Vocab at 0x16aaba4a8>,
#  'six': <gensim.models.keyedvectors.Vocab at 0x16aaba470>,
#  'party': <gensim.models.keyedvectors.Vocab at 0x16aaba358>,
#  'talks': <gensim.models.keyedvectors.Vocab at 0x16aaba320>,
#  'successful': <gensim.models.keyedvectors.Vocab at 0x16aaba208>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x16aaba1d0>,
#  'nicmar': <gensim.models.keyedvectors.Vocab at 0x16aaba0b8>,
#  'register': <gensim.models.keyedvectors.Vocab at 0x16aaba080>,
#  'domain': <gensim.models.keyedvectors.Vocab at 0x1539eb588>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x153a2a668>,
#  'older': <gensim.models.keyedvectors.Vocab at 0x16ab0bc18>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x16ab0b668>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x16ab0b208>,
#  'strongest': <gensim.models.keyedvectors.Vocab at 0x16a7e2ef0>,
#  'structure': <gensim.models.keyedvectors.Vocab at 0x16a7e2b38>,
#  'shape': <gensim.models.keyedvectors.Vocab at 0x16a7e2860>,
#  'compression': <gensim.models.keyedvectors.Vocab at 0x16a7e24a8>,
#  'cord': <gensim.models.keyedvectors.Vocab at 0x16a7e21d0>,
#  'matter': <gensim.models.keyedvectors.Vocab at 0x16aacaf28>,
#  'humans': <gensim.models.keyedvectors.Vocab at 0x16aacaef0>,
#  'selfish': <gensim.models.keyedvectors.Vocab at 0x16aacadd8>,
#  'evil': <gensim.models.keyedvectors.Vocab at 0x16aacada0>,
#  'passive': <gensim.models.keyedvectors.Vocab at 0x16aacac88>,
#  'transport': <gensim.models.keyedvectors.Vocab at 0x16aacac50>,
#  'cells': <gensim.models.keyedvectors.Vocab at 0x16aacab38>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x16aacab00>,
#  'bald': <gensim.models.keyedvectors.Vocab at 0x16aaca9e8>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x16aaca9b0>,
#  'shave': <gensim.models.keyedvectors.Vocab at 0x16aaca898>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x16aaca860>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x16aaca748>,
#  'grew': <gensim.models.keyedvectors.Vocab at 0x16aaca710>,
#  'loose': <gensim.models.keyedvectors.Vocab at 0x16aaca5f8>,
#  'ideal': <gensim.models.keyedvectors.Vocab at 0x16aaca5c0>,
#  'retirement': <gensim.models.keyedvectors.Vocab at 0x16aaca4a8>,
#  'stance': <gensim.models.keyedvectors.Vocab at 0x16aaca470>,
#  'possession': <gensim.models.keyedvectors.Vocab at 0x16aaca358>,
#  'weapons': <gensim.models.keyedvectors.Vocab at 0x16aaca320>,
#  'mass': <gensim.models.keyedvectors.Vocab at 0x16aaca208>,
#  'destruction': <gensim.models.keyedvectors.Vocab at 0x16aaca1d0>,
#  'north': <gensim.models.keyedvectors.Vocab at 0x16aaca198>,
#  'korea': <gensim.models.keyedvectors.Vocab at 0x16aaca160>,
#  'websites': <gensim.models.keyedvectors.Vocab at 0x16aaca048>,
#  'escorts': <gensim.models.keyedvectors.Vocab at 0x16a7b5ef0>,
#  'escort': <gensim.models.keyedvectors.Vocab at 0x16a7b5b38>,
#  'polo': <gensim.models.keyedvectors.Vocab at 0x16a7b5860>,
#  'diesel': <gensim.models.keyedvectors.Vocab at 0x16a7b54a8>,
#  'grand': <gensim.models.keyedvectors.Vocab at 0x16a7b51d0>,
#  'petrol': <gensim.models.keyedvectors.Vocab at 0x15982f048>,
#  'diet': <gensim.models.keyedvectors.Vocab at 0x15982f1d0>,
#  'growing': <gensim.models.keyedvectors.Vocab at 0x12b1e7400>,
#  'black': <gensim.models.keyedvectors.Vocab at 0x15fa0cba8>,
#  'hole': <gensim.models.keyedvectors.Vocab at 0x15fa0cb00>,
#  'morgan': <gensim.models.keyedvectors.Vocab at 0x15fa0cf98>,
#  'freeman': <gensim.models.keyedvectors.Vocab at 0x15fa0ce48>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x15fa0cc88>,
#  'says': <gensim.models.keyedvectors.Vocab at 0x15fa0cfd0>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x15fa0c860>,
#  'racism': <gensim.models.keyedvectors.Vocab at 0x15fa0c710>,
#  'talking': <gensim.models.keyedvectors.Vocab at 0x15fa0c5f8>,
#  'currently': <gensim.models.keyedvectors.Vocab at 0x15fa0c438>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x15fa0c3c8>,
#  'stock': <gensim.models.keyedvectors.Vocab at 0x15fa0c2b0>,
#  'options': <gensim.models.keyedvectors.Vocab at 0x15fa0c0b8>,
#  'rsus': <gensim.models.keyedvectors.Vocab at 0x15fa0c0f0>,
#  'uber': <gensim.models.keyedvectors.Vocab at 0x153e46fd0>,
#  'reviews': <gensim.models.keyedvectors.Vocab at 0x153e46eb8>,
#  'distribute': <gensim.models.keyedvectors.Vocab at 0x153e46e80>,
#  'identical': <gensim.models.keyedvectors.Vocab at 0x153e46d68>,
#  'pencils': <gensim.models.keyedvectors.Vocab at 0x153e46d30>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x153e46c18>,
#  'pencil': <gensim.models.keyedvectors.Vocab at 0x153e46be0>,
#  'apples': <gensim.models.keyedvectors.Vocab at 0x153e46ac8>,
#  'distributed': <gensim.models.keyedvectors.Vocab at 0x153e46a90>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x153e46978>,
#  'children': <gensim.models.keyedvectors.Vocab at 0x153e46940>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x153e46860>,
#  'hire': <gensim.models.keyedvectors.Vocab at 0x153e46828>,
#  'jerry': <gensim.models.keyedvectors.Vocab at 0x153e46748>,
#  'seinfeld': <gensim.models.keyedvectors.Vocab at 0x153e46710>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x153e46630>,
#  'tape': <gensim.models.keyedvectors.Vocab at 0x153e465f8>,
#  'hour': <gensim.models.keyedvectors.Vocab at 0x153e46518>,
#  'presentation': <gensim.models.keyedvectors.Vocab at 0x153e464e0>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x153e46400>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x153e463c8>,
#  'rabies': <gensim.models.keyedvectors.Vocab at 0x153e462e8>,
#  'vaccine': <gensim.models.keyedvectors.Vocab at 0x153e462b0>,
#  'non': <gensim.models.keyedvectors.Vocab at 0x153e461d0>,
#  'bite': <gensim.models.keyedvectors.Vocab at 0x153e46198>,
#  'exposure': <gensim.models.keyedvectors.Vocab at 0x153e460b8>,
#  'injection': <gensim.models.keyedvectors.Vocab at 0x153e46080>,
#  'dog': <gensim.models.keyedvectors.Vocab at 0x15efb4f60>,
#  'britain': <gensim.models.keyedvectors.Vocab at 0x15efb4f28>,
#  'ruled': <gensim.models.keyedvectors.Vocab at 0x15efb4e48>,
#  'standard': <gensim.models.keyedvectors.Vocab at 0x15efb4e10>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x15efb4d30>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x15efb4cf8>,
#  'relocation': <gensim.models.keyedvectors.Vocab at 0x15efb4c18>,
#  'afraid': <gensim.models.keyedvectors.Vocab at 0x15efb4be0>,
#  'working': <gensim.models.keyedvectors.Vocab at 0x15efb4b00>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x15efb4ac8>,
#  'red': <gensim.models.keyedvectors.Vocab at 0x15efb49e8>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x15efb49b0>,
#  'keys': <gensim.models.keyedvectors.Vocab at 0x15efb48d0>,
#  'lose': <gensim.models.keyedvectors.Vocab at 0x15efb4898>,
#  'virginity': <gensim.models.keyedvectors.Vocab at 0x15efb47b8>,
#  'forget': <gensim.models.keyedvectors.Vocab at 0x15efb4780>,
#  'wife': <gensim.models.keyedvectors.Vocab at 0x15efb46a0>,
#  'snoke': <gensim.models.keyedvectors.Vocab at 0x15efb4668>,
#  'killed': <gensim.models.keyedvectors.Vocab at 0x15efb4588>,
#  'emperor': <gensim.models.keyedvectors.Vocab at 0x15efb4550>,
#  'palpatine': <gensim.models.keyedvectors.Vocab at 0x15efb4470>,
#  'monetize': <gensim.models.keyedvectors.Vocab at 0x15efb4438>,
#  'videos': <gensim.models.keyedvectors.Vocab at 0x15efb4358>,
#  'upload': <gensim.models.keyedvectors.Vocab at 0x15efb4320>,
#  'copyright': <gensim.models.keyedvectors.Vocab at 0x15efb4240>,
#  'chances': <gensim.models.keyedvectors.Vocab at 0x15efb4208>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x15efb4128>,
#  'switch': <gensim.models.keyedvectors.Vocab at 0x15efb40f0>,
#  'canon': <gensim.models.keyedvectors.Vocab at 0x12b1e21d0>,
#  'leica': <gensim.models.keyedvectors.Vocab at 0x16575d400>,
#  'lux': <gensim.models.keyedvectors.Vocab at 0x16575d470>,
#  'tripod': <gensim.models.keyedvectors.Vocab at 0x16575d5f8>,
#  'members': <gensim.models.keyedvectors.Vocab at 0x16575d710>,
#  'moderation': <gensim.models.keyedvectors.Vocab at 0x16575d978>,
#  'nobody': <gensim.models.keyedvectors.Vocab at 0x16575da58>,
#  'answer': <gensim.models.keyedvectors.Vocab at 0x16575dda0>,
#  'funniest': <gensim.models.keyedvectors.Vocab at 0x16575df60>,
#  'joke': <gensim.models.keyedvectors.Vocab at 0x16575dc88>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x153e3ef60>,
#  'london': <gensim.models.keyedvectors.Vocab at 0x153e3ef28>,
#  'pm': <gensim.models.keyedvectors.Vocab at 0x153e3ee48>,
#  'deduction': <gensim.models.keyedvectors.Vocab at 0x153e3ee10>,
#  'pls': <gensim.models.keyedvectors.Vocab at 0x153e3ed30>,
#  'advice': <gensim.models.keyedvectors.Vocab at 0x153e3ecf8>,
#  'monthly': <gensim.models.keyedvectors.Vocab at 0x153e3ec18>,
#  'expenses': <gensim.models.keyedvectors.Vocab at 0x153e3ebe0>,
#  'saving': <gensim.models.keyedvectors.Vocab at 0x153e3eb00>,
#  'leaving': <gensim.models.keyedvectors.Vocab at 0x153e3eac8>,
#  'norway': <gensim.models.keyedvectors.Vocab at 0x153e3e9e8>,
#  'down': <gensim.models.keyedvectors.Vocab at 0x153e3e9b0>,
#  'mortgage': <gensim.models.keyedvectors.Vocab at 0x153e3e8d0>,
#  'sell': <gensim.models.keyedvectors.Vocab at 0x153e3e898>,
#  'apartment': <gensim.models.keyedvectors.Vocab at 0x153e3e7b8>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x153e3e780>,
#  'stereotypes': <gensim.models.keyedvectors.Vocab at 0x153e3e6a0>,
#  'kingdom': <gensim.models.keyedvectors.Vocab at 0x153e3e668>,
#  'americans': <gensim.models.keyedvectors.Vocab at 0x153e3e588>,
#  'twitter': <gensim.models.keyedvectors.Vocab at 0x153e3e550>,
#  'business': <gensim.models.keyedvectors.Vocab at 0x153e3e470>,
#  'source': <gensim.models.keyedvectors.Vocab at 0x153e3e438>,
#  'transfer': <gensim.models.keyedvectors.Vocab at 0x153e3e358>,
#  'skrill': <gensim.models.keyedvectors.Vocab at 0x153e3e320>,
#  'paypal': <gensim.models.keyedvectors.Vocab at 0x153e3e240>,
#  'send': <gensim.models.keyedvectors.Vocab at 0x153e3e208>,
#  'withdraw': <gensim.models.keyedvectors.Vocab at 0x153e3e128>,
#  'earphone': <gensim.models.keyedvectors.Vocab at 0x153e3e0f0>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x1686876d8>,
#  'bass': <gensim.models.keyedvectors.Vocab at 0x168687be0>,
#  'eligible': <gensim.models.keyedvectors.Vocab at 0x168687550>,
#  'yojana': <gensim.models.keyedvectors.Vocab at 0x168687f28>,
#  'employee': <gensim.models.keyedvectors.Vocab at 0x168687400>,
#  'forward': <gensim.models.keyedvectors.Vocab at 0x168687278>,
#  'engineering': <gensim.models.keyedvectors.Vocab at 0x15fab0fd0>,
#  'fields': <gensim.models.keyedvectors.Vocab at 0x15fab0f98>,
#  'suit': <gensim.models.keyedvectors.Vocab at 0x15fab0eb8>,
#  'abusing': <gensim.models.keyedvectors.Vocab at 0x15fab0e80>,
#  'abusive': <gensim.models.keyedvectors.Vocab at 0x15fab0da0>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x15fab0d68>,
#  'ex': <gensim.models.keyedvectors.Vocab at 0x15fab0c88>,
#  'past': <gensim.models.keyedvectors.Vocab at 0x15fab0c50>,
#  'coworkers': <gensim.models.keyedvectors.Vocab at 0x15fab0b70>,
#  'bosses': <gensim.models.keyedvectors.Vocab at 0x15fab0b38>,
#  'attract': <gensim.models.keyedvectors.Vocab at 0x15fab0a58>,
#  'gross': <gensim.models.keyedvectors.Vocab at 0x15fab0a20>,
#  'ctc': <gensim.models.keyedvectors.Vocab at 0x15fab0940>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x15fab0908>,
#  'weekly': <gensim.models.keyedvectors.Vocab at 0x15fab0828>,
#  'paycheck': <gensim.models.keyedvectors.Vocab at 0x15fab07f0>,
#  'yearly': <gensim.models.keyedvectors.Vocab at 0x15fab0710>,
#  'employer': <gensim.models.keyedvectors.Vocab at 0x15fab06d8>,
#  'agreed': <gensim.models.keyedvectors.Vocab at 0x15fab05f8>,
#  'upon': <gensim.models.keyedvectors.Vocab at 0x15fab05c0>,
#  'towns': <gensim.models.keyedvectors.Vocab at 0x15fab04e0>,
#  'kerala': <gensim.models.keyedvectors.Vocab at 0x15fab04a8>,
#  'confidence': <gensim.models.keyedvectors.Vocab at 0x15fab03c8>,
#  'clarity': <gensim.models.keyedvectors.Vocab at 0x15fab0390>,
#  'anyone': <gensim.models.keyedvectors.Vocab at 0x15fab02b0>,
#  ...}

# %%
word = 'trump'
print(f"Word {word} is represented by {len(w2v_model.wv[word])}-dim vector:")
w2v_model.wv[word]
# Out:
# Word trump is represented by 150-dim vector:
# array([ 3.3107355 ,  0.8425358 ,  4.1214967 ,  0.16413495, -1.8511533 ,
#         0.5406486 , -1.0591987 ,  2.2244828 , -1.127227  , -2.043492  ,
#         0.34423184, -0.58979374, -1.942646  , -2.915745  ,  2.1186101 ,
#         1.3629088 , -2.0968988 , -1.2693385 ,  1.4190816 , -1.4458344 ,
#        -2.2402678 , -1.7194806 ,  0.18369651, -1.0895953 , -0.17645195,
#         4.461869  , -0.7583205 , -3.6195562 , -1.4466676 , -0.28347042,
#         0.1111536 ,  2.6102455 ,  1.2059026 ,  2.3565419 ,  2.6914415 ,
#        -1.6903051 ,  2.6847966 , -1.995088  ,  0.32408017,  1.7590213 ,
#         1.528895  ,  1.3157607 , -1.6772395 , -0.38203248, -1.6400788 ,
#        -0.43243533,  3.3234317 , -0.991555  , -2.2962174 ,  0.4065657 ,
#         4.102692  ,  4.671234  , -3.3851779 , -3.5112364 , -1.0444226 ,
#        -1.6023419 ,  0.40471596, -0.45547566, -2.298546  ,  1.613397  ,
#         2.619818  ,  1.1592376 ,  1.7702707 , -1.5848597 , -0.74017453,
#         0.68113613,  0.22783634,  0.5760455 ,  4.014598  ,  2.8273344 ,
#         1.1797863 , -0.52696764,  2.212877  ,  2.5504856 ,  3.3269787 ,
#        -5.0177503 , -0.4792756 , -3.209486  , -0.61466753, -1.7778015 ,
#         2.5521078 ,  0.5658082 , -3.710762  , -2.0143893 ,  0.69198024,
#        -0.9113625 ,  0.9564561 , -0.35362545, -1.7753941 , -2.3377295 ,
#         1.1614246 , -0.3289891 ,  1.7183084 ,  2.347059  , -0.19193937,
#        -2.8291283 , -0.92389506,  3.188477  , -2.787876  ,  0.65380186,
#         4.7685785 ,  3.2750971 ,  2.1765141 , -0.62862253,  0.5765326 ,
#        -1.124207  , -2.3447495 , -1.499772  , -0.02610442,  1.4072447 ,
#        -2.1687837 ,  1.2858077 , -1.7965192 , -0.5458992 ,  4.839782  ,
#         0.5406968 , -1.9659995 ,  0.35138842, -1.7226725 , -0.10583708,
#        -2.9535367 , -4.2306223 , -0.47709456,  1.3766006 ,  0.04250675,
#         0.36258623, -3.5018482 ,  0.01096552, -0.25515163, -2.6407897 ,
#         0.06642656, -0.53002286, -1.0523074 , -0.0371708 ,  0.7395177 ,
#        -3.1105056 ,  3.9699576 , -1.2788051 , -1.3195622 ,  2.1123204 ,
#         0.98698545,  0.6800538 ,  5.173388  ,  0.3868588 ,  0.26562098,
#         1.4089905 , -3.3133256 ,  0.7860044 , -0.4638092 ,  3.5053716 ],
#       dtype=float32)

# %%
# TSNE representation of N words
N = 1000
wanted_vocab = random.sample(list(w2v_model.wv.vocab), N)
X = w2v_model[wanted_vocab] # X is an array of word vectors, each vector containing 150 tokens
tsne_model = TSNE(perplexity=40, n_components=2, init="pca", n_iter=5000, random_state=23)
Y = tsne_model.fit_transform(X)
# Out:
# /Users/viktor.sohajek/mg_tech_breaks/word2vec/venv_word2vec/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning:
#
# Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
# Plot
trace = go.Scatter(
    x = Y[:,0],
    y = Y[:,1],
    text = list(wanted_vocab),
    mode='text'
)

data = [trace]

# Plot and embed in ipython notebook!
iplot(data, filename='basic-scatter')
# Out:
# <div id="f01b85e2-90a5-4dae-bc52-cb3590bbd65f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("f01b85e2-90a5-4dae-bc52-cb3590bbd65f")) {
#     Plotly.newPlot("f01b85e2-90a5-4dae-bc52-cb3590bbd65f", [{"mode": "text", "text": ["luxurious", "andromeda", "jaya", "spasm", "fortiguard", "livestream", "oppressive", "anakin", "chanakya", "prostate", "exists", "portal", "lettuce", "lifebydesign", "tests", "hanoi", "nitk", "associated", "freaked", "allah", "cakes", "prozac", "medical", "fingerprint", "coating", "hurricanes", "whereas", "straps", "carlos", "wittgenstein", "scored", "humanity", "retaliate", "apartheid", "agency", "invites", "quadcopter", "fitclown", "viscous", "cersei", "passenger", "everywhere", "indicators", "bpm", "grilled", "occasion", "res", "downside", "sharif", "successfully", "bonaparte", "lamborghini", "mag", "gmail", "srour", "balkan", "cow", "yunnan", "matrimonial", "repent", "framer", "vienna", "appending", "merger", "delirium", "mischievous", "accommodate", "inmobi", "phenomenon", "odin", "stop", "nootropics", "guards", "calhoun", "conference", "pneumatic", "madinah", "reelected", "grabbed", "doctrines", "reimburse", "hackathons", "octane", "atheists", "prosperous", "parachute", "puja", "lipton", "imagined", "clearer", "bridge", "grinder", "receiver", "resolutions", "dealt", "shaktimaan", "missing", "aegon", "constellation", "alkali", "assembling", "gal", "handed", "deposit", "document", "arrangement", "keeping", "tourister", "finalize", "explodes", "sitesmatrix", "intimidating", "ejaculates", "ritual", "learners", "iimc", "epoch", "showcase", "delegation", "precedent", "biased", "mcd", "crises", "nicotine", "keeps", "listings", "moons", "stratified", "baba", "malta", "lake", "porno", "thesaurus", "elder", "domains", "loneliness", "bansal", "koh", "comsol", "hd", "transact", "pregnancy", "firms", "decided", "sharpie", "jolie", "sedan", "impotent", "neerja", "herb", "deserve", "imbalance", "selecting", "lightening", "sandler", "vitamin", "verses", "truss", "nyc", "seller", "psychics", "blackbody", "merge", "nimcet", "retake", "klonopin", "uranium", "resize", "prasad", "nespresso", "repeaters", "hcl", "checkmark", "fpga", "consciousness", "event", "purchased", "interacting", "dom", "molds", "month", "valmiki", "mountbatten", "mystery", "parks", "look", "adobe", "wore", "cellular", "balsamic", "reacts", "thoughtful", "bestmytest", "measurements", "significant", "wasting", "generational", "tuned", "buffer", "blunders", "xerox", "warby", "lonavala", "realise", "throughout", "incestuous", "loudly", "innovations", "blogging", "acetic", "vitae", "daydream", "thackeray", "unreleased", "pradhan", "potency", "brooms", "rime", "randolph", "cult", "jars", "telepathy", "disobey", "hgh", "chiseled", "clause", "doorstep", "suffolk", "bachchan", "greyhound", "martyn", "lords", "aluminium", "candies", "authentic", "cardiologist", "noses", "enjoys", "cinese", "baseball", "power", "etfs", "listerine", "mo", "strenuous", "photographers", "levant", "fetch", "learn", "intern", "fuel", "provisional", "vertebrates", "incubators", "yukata", "overpriced", "cayenne", "deadshot", "delegates", "trail", "nypd", "justin", "anil", "youthful", "plane", "jericho", "gem", "typewriter", "shobhit", "speaking", "acl", "unsupervised", "rts", "mri", "less", "heater", "inventors", "preschools", "deficits", "kvpy", "nikesh", "dealership", "windsurfing", "assassins", "retweeted", "hesitation", "pdfs", "opponent", "metrocard", "bryant", "alone", "domesticated", "disadvantaged", "pumpkins", "bible", "thinkers", "brad", "spiderman", "cheaters", "proud", "kyc", "expose", "seeks", "gerrymandering", "flappy", "vertebrate", "labelled", "krazybutterfly", "dribbble", "mosques", "wine", "doing", "cares", "nba", "devolution", "calling", "mcom", "dx", "toefl", "advising", "george", "baptized", "lego", "cousin", "limbo", "boon", "winding", "directory", "powerbank", "analyst", "moses", "provocative", "cma", "orbitz", "carlsen", "wines", "pairing", "server", "intraday", "cr", "purported", "septum", "demonetizing", "homemade", "pendrive", "jokers", "barbuda", "tesseract", "prank", "temperature", "special ...

# %% [markdown]
# ## Using the model

# %%
# Find similar word 1
words1 = ['trump']
w2v_model.wv.most_similar(positive=words1, topn=10)
# Out:
# [('trumps', 0.7672150135040283),
#  ('knuth', 0.6954089999198914),
#  ('hoffman', 0.6228437423706055),
#  ('bernie', 0.5904607772827148),
#  ('obama', 0.5755990743637085),
#  ('hillary', 0.5698307752609253),
#  ('democrats', 0.5683139562606812),
#  ('sanders', 0.5480324029922485),
#  ('president', 0.5426574945449829),
#  ('election', 0.5415182113647461)]

# %%
# Find similar word 2
words1 = ['panda', 'rabbit', 'dog']
w2v_model.wv.most_similar(positive=words1, topn=10)
# Out:
# [('pug', 0.748351514339447),
#  ('fleas', 0.7307619452476501),
#  ('chow', 0.7273343801498413),
#  ('rib', 0.7270840406417847),
#  ('hamster', 0.7243354320526123),
#  ('shih', 0.7230414748191833),
#  ('brindle', 0.7135178446769714),
#  ('snake', 0.7134368419647217),
#  ('ketchup', 0.7119420170783997),
#  ('broccoli', 0.7117798328399658)]

# %%
# Find similar word 4
words1 = ['husband', 'man']
words2 = ['woman']
w2v_model.wv.most_similar(positive=words1, negative=words2, topn=10)
# Out:
# [('wife', 0.7469571828842163),
#  ('son', 0.7107111811637878),
#  ('daughter', 0.6980760097503662),
#  ('mother', 0.6955826282501221),
#  ('father', 0.6858428120613098),
#  ('dad', 0.6769495010375977),
#  ('brother', 0.6665967702865601),
#  ('sister', 0.6537143588066101),
#  ('mom', 0.6525180339813232),
#  ('boyfriend', 0.6416940689086914)]

# %%
# Find similar word 5
words1 = ['president', 'trump']
words2 = ['strength']
w2v_model.wv.most_similar(positive=words1, negative=words2, topn=10)
# Out:
# [('obama', 0.6424059271812439),
#  ('trumps', 0.6129918098449707),
#  ('congress', 0.5975081920623779),
#  ('elected', 0.5833556056022644),
#  ('barack', 0.5784204006195068),
#  ('democrats', 0.5746055245399475),
#  ('bernie', 0.5696306824684143),
#  ('republican', 0.568333625793457),
#  ('knuth', 0.5595422387123108),
#  ('elect', 0.5541716814041138)]

# %%
# Find similar word 4
words1 = ['programming','beginner']
words2 = []
w2v_model.wv.most_similar(positive=words1, negative=words2, topn=10)
# Out:
# [('python', 0.7925356030464172),
#  ('java', 0.7660596370697021),
#  ('coding', 0.7453685402870178),
#  ('javascript', 0.7324598431587219),
#  ('php', 0.7028157114982605),
#  ('programmer', 0.7022966146469116),
#  ('framework', 0.6619861125946045),
#  ('beginners', 0.654211163520813),
#  ('learning', 0.6265166401863098),
#  ('tutorial', 0.6224186420440674)]

# %%
# What should not be there? 1
w2v_model.wv.doesnt_match(['tesla', 'bmw', 'superman', 'mercedes'])
# Out:
# /Users/viktor.sohajek/mg_tech_breaks/word2vec/venv_word2vec/lib/python3.6/site-packages/gensim/models/keyedvectors.py:858: FutureWarning:
#
# arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
# 'superman'

# %%
# What should not be there? 2
w2v_model.wv.doesnt_match(['trump', 'president', 'wall', 'business'])
# Out:
# 'business'

# %%
# What should not be there? 3
w2v_model.wv.doesnt_match(['weed', 'beer', 'herion', 'cocain'])
# Out:
# 'weed'

# %% [markdown]
# ## Sources
# [Wiki](https://en.wikipedia.org/wiki/Word2vec)
#
# [Good Article 1](https://blog.acolyer.org/2016/04/21/the-amazing-power-of-word-vectors/)
#
# [Good Article 1](http://kavita-ganesan.com/gensim-word2vec-tutorial-starter-code/#.XJfruC1_HUo)
#
# [Tensor Flow Article](https://www.tensorflow.org/tutorials/representation/word2vec)
